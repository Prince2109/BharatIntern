# %% [markdown]
# # Stock Prediction
# ### stock price predicts using LSTM

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('Reliance.csv')

df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2015-11-18   463.799988   465.649994   454.975006   456.000000
# 1    2015-11-19   459.450012   469.350006   458.625000   467.375000
# 2    2015-11-20   467.000000   476.399994   462.774994   473.424988
# 3    2015-11-23   475.000000   478.950012   473.100006   476.875000
# 4    2015-11-24   476.500000   485.799988   475.524994   483.850006
# ...         ...          ...          ...          ...          ...
# 1228 2020-11-10  2077.000000  2090.000000  2041.199951  2084.550049
# 1229 2020-11-11  2089.000000  2095.000000  1978.099976  1997.199951
# 1230 2020-11-12  1981.000000  2008.449951  1965.000000  1980.000000
# 1231 2020-11-13  1982.000000  2036.650024  1981.750000  1996.400024
# 1232 2020-11-17  2085.000000  2085.000000  1985.000000  1993.250000
#
#         Adj Close      Volume
# 0      436.671021   5142766.0
# 1      447.563873   5569752.0
# 2      453.357422   5167930.0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace = True)

# %%
df.corr()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_12940\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999444  0.999528  0.998973   0.998959  0.395079
# High       0.999444  1.000000  0.999293  0.999607   0.999613  0.410930
# Low        0.999528  0.999293  1.000000  0.999541   0.999497  0.387160
# Close      0.998973  0.999607  0.999541  1.000000   0.999977  0.401374
# Adj Close  0.998959  0.999613  0.999497  0.999977   1.000000  0.402433
# Volume     0.395079  0.410930  0.387160  0.401374   0.402433  1.000000

# %%
df.corr(numeric_only=True)
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999444  0.999528  0.998973   0.998959  0.395079
# High       0.999444  1.000000  0.999293  0.999607   0.999613  0.410930
# Low        0.999528  0.999293  1.000000  0.999541   0.999497  0.387160
# Close      0.998973  0.999607  0.999541  1.000000   0.999977  0.401374
# Adj Close  0.998959  0.999613  0.999497  0.999977   1.000000  0.402433
# Volume     0.395079  0.410930  0.387160  0.401374   0.402433  1.000000

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming you have a DataFrame named 'df' with columns: Open, High, Low, Close, Adj Close, and Volume

# Create a figure and axis for the plot

# Plot each column using the DataFrame and specify labels
plt.subplot(611)
plt.title("Date vs Open")
plt.plot(df['Date'], df['Open'])
plt.xlabel("Date")
plt.ylabel("Open")
plt.subplot(612)
plt.title("Date vs High")
plt.plot(df['Date'], df['High'])
plt.xlabel("Date")
plt.ylabel("High")
plt.subplot(613)
plt.title("Date vs Low")
plt.plot(df['Date'], df['Low'])
plt.xlabel("Date")
plt.ylabel("Low")
plt.subplot(614)
plt.title("Date vs Close")
plt.plot(df['Date'], df['Close'])
plt.xlabel("Date")
plt.ylabel("Close")
plt.subplot(615)
plt.title("Date vs Adj Close")
plt.plot(df['Date'], df['Adj Close'])
plt.xlabel("Date")
plt.ylabel("Adj Close")
plt.subplot(616)
plt.xlabel("Date")
plt.ylabel("Volume")
plt.title("Date vs Volume")
plt.plot(df['Date'], df['Volume'])
plt.subplots_adjust(top=4.8)
# Show the plot
plt.show()
